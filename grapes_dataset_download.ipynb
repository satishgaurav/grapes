# %%
from google_images_download import google_images_download

#instantiate the class
response = google_images_download.googleimagesdownload()
arguments = {"keywords":"green grapes, red grapes",
             "limit":50,"print_urls":False}
paths = response.download(arguments)

#print complete paths to the downloaded images
print(paths)
# Out:
# Item no.: 1 --> Item name = green grapes
# Evaluating...
# Starting Download...
# Completed Image ====> 1.green-grapes.jpg
# Completed Image ====> 2.green-grapes-500x500.jpg
# Completed Image ====> 3.green-grapes-500x500.jpg
# Completed Image ====> 4.1224.png
# Completed Image ====> 5.seedless-grapes-1571218095-5118465.jpeg
# Completed Image ====> 6.seedless-green-grapes-500x500.jpg
# Completed Image ====> 7.grapes-green-1900.png
# Completed Image ====> 8.96878646-texture-grape-bunch-of-fresh-grapes-fresh-green-grapes-healthy-fruits-wine-grapes-background-green-w.jpg
# URLError on an image...trying next one... Error: HTTP Error 404: Not Found
# Completed Image ====> 9.green_grapes_dsc9494-(2).jpg
# Completed Image ====> 10.6000200557738.jpg
# Completed Image ====> 11.0018501_green-grapes-seedless_550.jpeg
# Completed Image ====> 12.af49eb1d49ea7caaf4db0aa6777fc399.jpg
# Completed Image ====> 13.yellow-or-green-grapes-branch-with-leaves-vector-25870521.jpg
# ...

# %%
from google_images_download import google_images_download

#instantiate the class
response = google_images_download.googleimagesdownload()
arguments = {"keywords":"black grapes, yellow grapes",
             "limit":50,"print_urls":False}
paths = response.download(arguments)

#print complete paths to the downloaded images
print(paths)
# Out:
# Item no.: 1 --> Item name = black grapes
# Evaluating...
# Starting Download...
# Completed Image ====> 1.9-powerful-reasons-you-must-eat-black-grapes.jpg
# Completed Image ====> 2.black-seedless-grapes-500x500.jpg
# Completed Image ====> 3.1222.png
# Completed Image ====> 4.black-or-blue-bunch-grapes-in-hand-old-senior-farmer-shutterstock_717869458.jpg
# Completed Image ====> 5.untitled-500x500.png
# Completed Image ====> 6.black-grapes.jpg
# Completed Image ====> 7.black-grapes_625x350_51472115863.jpg.webp
# Completed Image ====> 8.0018891_black-grapes_550.jpeg
# Completed Image ====> 9.untitled-2113410.png
# Completed Image ====> 10.51ejdfdqf%2bl._ac_ul474_sr474,450_.jpg
# Completed Image ====> 11.best-black-grapes-benefits-for-skin-hair-health.jpg.webp.jpg
# Completed Image ====> 12.black_grapes_grafted_seedless_live_plant.jpg
# Completed Image ====> 13.black-seedless-grapes.jpg
# Completed Image ====> 14.fresh-black-grapes-500x500.jpg
# Completed Image ====> 15.grapes.jpg
# ...

# %%
from google_images_download import google_images_download

#instantiate the class
response = google_images_download.googleimagesdownload()
arguments = {"keywords":"pink grapes, purple grapes",
             "limit":50,"print_urls":False}
paths = response.download(arguments)

#print complete paths to the downloaded images
print(paths)
# Out:
# Item no.: 1 --> Item name = pink grapes
# Evaluating...
# Starting Download...
# Completed Image ====> 1.87393102-banch-of-pink-grapes-in-a-garden.jpg
# Completed Image ====> 2.pink-grapes-japan-2-1024x683.jpg
# Completed Image ====> 3.white-grape-water-drops-closeup-260nw-123320878.jpg
# Completed Image ====> 4.7811100-pink-grape-isolated-on-white.jpg
# Completed Image ====> 5.b9326902009z.1_20170328111954_000_ghphsp204.1-0.jpg
# Completed Image ====> 6.bunch-pink-grapes-18966308.jpg
# Completed Image ====> 7.dmcma8956.jpg
# Completed Image ====> 8.bb0d1795d1ed89f312b9dc3e00d72834.jpg
# Completed Image ====> 9.41lphgrandl.jpg
# Completed Image ====> 10.bunch-of-grapes-stock-illustration-3278430.jpg
# Completed Image ====> 11.836d04601aea85bd68078d8aa7ab8071.jpg
# Completed Image ====> 12.red-pink-muscatel-and-white-table-grapes-wine-grapes-vector-id1132428365.jpg
# Completed Image ====> 13.red-grapes-pink-sweet-moment-wine-old-vine-61887616.jpg
# ...
